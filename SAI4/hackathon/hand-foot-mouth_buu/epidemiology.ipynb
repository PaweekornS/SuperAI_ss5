# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Train_set.csv', index_col='_id')
df.head()
# Out:
#              Disease  Year PROVINCE  Week_no  Count
# _id
# 1    Hand Foot Mouth  2013  Bangkok        1   62.0
# 2    Hand Foot Mouth  2013  Bangkok        2   95.0
# 3    Hand Foot Mouth  2013  Bangkok        3   88.0
# 4    Hand Foot Mouth  2013  Bangkok        4   86.0
# 5    Hand Foot Mouth  2013  Bangkok        5  132.0

# %% [markdown]
# ### Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40194 entries, 1 to 40194
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Disease   40194 non-null  object
#  1   Year      40194 non-null  int64
#  2   PROVINCE  40194 non-null  object
#  3   Week_no   40194 non-null  int64
#  4   Count     40194 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.8+ MB

# %%
df['Date'] = pd.to_datetime(df['Year'].astype(str) + (df['Week_no'] - 1).astype(str) + '2', format='%Y%W%w')
df.set_index('Date', inplace=True)
df
# Out:
#                     Disease  Year    PROVINCE  Week_no  Count
# Date
# 2013-01-01  Hand Foot Mouth  2013     Bangkok        1   62.0
# 2013-01-08  Hand Foot Mouth  2013     Bangkok        2   95.0
# 2013-01-15  Hand Foot Mouth  2013     Bangkok        3   88.0
# 2013-01-22  Hand Foot Mouth  2013     Bangkok        4   86.0
# 2013-01-29  Hand Foot Mouth  2013     Bangkok        5  132.0
# ...                     ...   ...         ...      ...    ...
# 2022-11-22  Hand Foot Mouth  2022  Narathiwat       48   13.0
# 2022-11-29  Hand Foot Mouth  2022  Narathiwat       49   11.0
# 2022-12-06  Hand Foot Mouth  2022  Narathiwat       50    6.0
# 2022-12-13  Hand Foot Mouth  2022  Narathiwat       51   13.0
# 2022-12-20  Hand Foot Mouth  2022  Narathiwat       52   12.0
#
# [40194 rows x 5 columns]

# %%
df = df.sort_values(['Year', 'Week_no', 'Count'])
df.drop(columns=['Disease', 'Year'], inplace=True)
df
# Out:
#                     PROVINCE  Week_no  Count
# Date
# 2013-01-01     Maha Sarakham        1    1.0
# 2013-01-01        Chiang Mai        1    1.0
# 2013-01-01               Nan        1    1.0
# 2013-01-01             Satun        1    1.0
# 2013-01-01        Chaiyaphum        1    2.0
# ...                      ...      ...    ...
# 2022-12-20  Ubon Ratchathani       52   19.0
# 2022-12-20       Surat Thani       52   19.0
# 2022-12-20       Chanthaburi       52   21.0
# 2022-12-20            Phuket       52   36.0
# 2022-12-20        Chiang Rai       52   49.0
#
# [40194 rows x 3 columns]

# %%
slice = df[(df.index >= '2013-01-01') & (df.index <= '2014-12-31') & (df['PROVINCE'] == 'Nonthaburi')]
plt.plot(slice.index, slice['Count'])

# %%
def check_stationary(df, label):
    temp_df = df.copy()
    temp_df['roll_mean'] = temp_df[label].rolling(52).mean()
    temp_df['roll_std'] = temp_df[label].rolling(52).std()

    plt.plot(temp_df.index, temp_df[label], label='raw')
    plt.plot(temp_df.index, temp_df['roll_mean'], label='mean')
    plt.plot(temp_df.index, temp_df['roll_std'], label='std')

    plt.legend()
    
check_stationary(df, 'Count')

# %% [markdown]
# ### Feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df_prep = df[df.index > '2021-12-31'].copy()

# clean 0 for log testing
log_clean = [ x + 1 if x == 0 else x for x in df_prep['Count'].values ]

encode = LabelEncoder()
df_prep['provinceID'] = encode.fit_transform(df_prep['PROVINCE'])
df_prep
# Out:
#                     PROVINCE  Week_no  Count  provinceID
# Date
# 2022-01-04      Samut Prakan        2    1.0          56
# 2022-01-04      Pathum Thani        2    1.0          36
# 2022-01-04         Ang Thong        2    1.0           1
# 2022-01-04           Lopburi        2    1.0          21
# 2022-01-04          Saraburi        2    1.0          59
# ...                      ...      ...    ...         ...
# 2022-12-20  Ubon Ratchathani       52   19.0          71
# 2022-12-20       Surat Thani       52   19.0          66
# 2022-12-20       Chanthaburi       52   21.0           8
# 2022-12-20            Phuket       52   36.0          47
# 2022-12-20        Chiang Rai       52   49.0          10
#
# [3927 rows x 4 columns]

# %%
def lag_province_diff(df, label, lag=4):
    temp = pd.DataFrame(columns=df.columns, index=df.index)
    temp[f'lag{lag}_diff'] = 0
    temp.dropna(inplace=True)
    for province in df['PROVINCE'].unique():
        province_df = df[ df['PROVINCE'] == province ].copy()
        province_df[f'lag{lag}_diff'] = df[ df['PROVINCE'] == province ][label].diff(lag)
        temp = pd.concat([temp, province_df])
        
    return temp

df_prep = lag_province_diff(df_prep, 'Count', lag=4)
df_prep = lag_province_diff(df_prep, 'Count', lag=8)
df_prep = lag_province_diff(df_prep, 'Count', lag=12)
df_prep
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_18340\3697179531.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   temp = pd.concat([temp, province_df])
# C:\Users\ACER\AppData\Local\Temp\ipykernel_18340\3697179531.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   temp = pd.concat([temp, province_df])
# C:\Users\ACER\AppData\Local\Temp\ipykernel_18340\3697179531.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   temp = pd.concat([temp, province_df])
#                 PROVINCE Week_no  Count provinceID  lag4_diff  lag8_diff  \
# Date
# 2022-01-04  Samut Prakan       2    1.0         56        NaN        NaN
# 2022-01-11  Samut Prakan       3    8.0         56        NaN        NaN
# 2022-01-18  Samut Prakan       4    1.0         56        NaN        NaN
# 2022-01-25  Samut Prakan       5    2.0         56        NaN        NaN
# 2022-02-01  Samut Prakan       6    1.0         56        0.0        NaN
# ...                  ...     ...    ...        ...        ...        ...
# 2022-11-22    Chiang Rai      48  112.0         10       59.0       15.0
# 2022-11-29    Chiang Rai      49   93.0         10       20.0       -2.0
# 2022-12-06    Chiang Rai      50   99.0         10        3.0       29.0
# 2022-12-13    Chiang Rai      51   71.0         10      -34.0       10.0
# 2022-12-20    Chiang Rai      52   49.0         10      -63.0       -4.0
#
#             lag12_diff
# Date
# 2022-01-04         NaN
# 2022-01-11         NaN
# 2022-01-18         NaN
# 2022-01-25         NaN
# 2022-02-01         NaN
# ...                ...
# 2022-11-22        12.0
# 2022-11-29         8.0
# 2022-12-06       -14.0
# 2022-12-13       -37.0
# 2022-12-20       -48.0
#
# [3927 rows x 7 columns]

# %%
check_stationary(df_prep.sort_values(['Date']), 'lag12_diff')

# %%
from statsmodels.tsa.stattools import adfuller

adf_score = adfuller(df_prep['lag12_diff'].dropna(), autolag='AIC')
stats = pd.Series(adf_score[0:4], index=['Test statistics', 'p-value', '#lag-used', 'number of observations used'])
stats
# Out:
# Test statistics               -1.551071e+01
# p-value                        2.350598e-28
# #lag-used                      2.800000e+01
# number of observations used    2.974000e+03
# dtype: float64

# %%
for key, value in adf_score[4].items():
    print(f'confidence interval {key}:  {value}')
# Out:
# confidence interval 1%:  -3.4325507240185105
# confidence interval 5%:  -2.862512336314338
# confidence interval 10%:  -2.5672876007125645

# %% [markdown]
# ### SARIMAX

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
pacf = plot_pacf(df_prep['lag12_diff'].dropna(), lags=20) # p
acf = plot_acf(df_prep['lag12_diff'].dropna(), lags=20)  # q

# %%
check_stationary(df_prep.sort_values(['Date']), 'Count')

# %%
model = SARIMAX(df_prep['Count'].values, exog=df_prep['provinceID'].values,
                order=(1, 1, 0), seasonal_order=(1, 1, 0, 12))
model_fit = model.fit()
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 3927
# Model:             SARIMAX(1, 1, 0)x(1, 1, 0, 12)   Log Likelihood              -17923.976
# Date:                            Mon, 16 Sep 2024   AIC                          35855.951
# Time:                                    06:13:09   BIC                          35881.040
# Sample:                                         0   HQIC                         35864.854
#                                            - 3927
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0008      0.113      0.007      0.995      -0.220       0.222
# ar.L1          0.3280      0.006     59.403      0.000       0.317       0.339
# ar.S.L12      -0.5087      0.005    -97.137      0.000      -0.519      -0.498
# sigma2       555.6128      3.923    141.624      0.000     547.924     563.302
# ===================================================================================
# Ljung-Box (L1) (Q):                  27.82   Jarque-Bera (JB):             55989.61
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.49   Skew:                            -0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# %%
lstm_df = df_prep.sort_values(['Date', 'provinceID']).copy()
lstm_df.drop(columns=['PROVINCE', 'Week_no'], inplace=True)
lstm_df.dropna(inplace=True)

lstm_df['provinceID'] = lstm_df['provinceID'].astype('int')
lstm_df
# Out:
#             Count  provinceID  lag4_diff  lag8_diff  lag12_diff
# Date
# 2022-03-29    8.0           0        0.0        0.0         0.0
# 2022-03-29    8.0           1        0.0        0.0         7.0
# 2022-03-29   10.0           2        1.0        6.0         3.0
# 2022-03-29    8.0           3        0.0        0.0         0.0
# 2022-03-29    8.0           4        7.0        7.0         0.0
# ...           ...         ...        ...        ...         ...
# 2022-12-20    8.0          72        0.0        0.0         0.0
# 2022-12-20    1.0          73       -7.0       -2.0       -18.0
# 2022-12-20    4.0          74        3.0        2.0       -18.0
# 2022-12-20    5.0          75      -11.0        1.0         2.0
# 2022-12-20    9.0          76        1.0        3.0        -2.0
#
# [3003 rows x 5 columns]

# %%
train, valid = np.split(lstm_df, [int(len(lstm_df)*0.8)])
train_date, valid_date = train.index, valid.index

train.reset_index(drop=True, inplace=True)
valid.reset_index(drop=True, inplace=True)

X_train, y_train = train.drop(columns=['Count']), train['Count']
X_valid, y_valid = valid.drop(columns=['Count']), valid['Count']
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
model = Sequential([
    layers.Input((3, 1)), 
    layers.LSTM(64),
    layers.Dense(32, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=200)
# Out:
# Epoch 1/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8438.8457 - mean_absolute_error: 41.4064 - val_loss: 231.6830 - val_mean_absolute_error: 7.0003
# Epoch 2/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4693.3584 - mean_absolute_error: 24.1871 - val_loss: 223.5324 - val_mean_absolute_error: 7.8004
# Epoch 3/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 945.7783 - mean_absolute_error: 9.6450 - val_loss: 217.3424 - val_mean_absolute_error: 7.2752
# Epoch 4/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 578.1994 - mean_absolute_error: 8.3413 - val_loss: 205.6665 - val_mean_absolute_error: 6.8384
# Epoch 5/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 242.1486 - mean_absolute_error: 6.4808 - val_loss: 195.2775 - val_mean_absolute_error: 7.0004
# Epoch 6/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 173.6688 - mean_absolute_error: 6.2967 - val_loss: 205.5957 - val_mean_absolute_error: 6.4839
# Epoch 7/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 178.0446 - mean_absolute_error: 6.1923 - val_loss: 200.0083 - val_mean_absolute_error: 6.4558
# Epoch 8/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 214.4178 - mean_absolute_error: 6.4359 - val_loss: 203.9271 - val_mean_absolute_error: 6.3865
# Epoch 9/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 141.5858 - mean_absolute_error: 5.5205 - val_loss: 192.5366 - val_mean_absolute_error: 6.4037
# Epoch 10/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 156.2317 - mean_absolute_error: 6.0673 - val_loss: 197.5542 - val_mean_absolute_error: 6.3982
# Epoch 11/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 120.0896 - mean_absolute_error: 5.7375 - val_loss: 197.4361 - val_mean_absolute_error: 6.3644
# Epoch 12/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 108.7515 - mean_absolute_error: 5.3249 - val_loss: 194.8570 - val_mean_absolute_error: 6.8103
# Epoch 13/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 213.2753 - mean_absolute_error: 6.8971 - val_loss: 195.4266 - val_mean_absolute_error: 6.6580
# Epoch 14/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 138.5663 - mean_absolute_error: 5.4607 - val_loss: 196.7410 - val_mean_absolute_error: 6.8327
# Epoch 15/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 100.2933 - mean_absolute_error: 5.1333 - val_loss: 193.8260 - val_mean_absolute_error: 6.5271
# Epoch 16/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 96.2706 - mean_absolute_error: 4.9585 - val_loss: 200.6897 - val_mean_absolute_error: 6.4622
# Epoch 17/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 104.6351 - mean_absolute_error: 5.2004 - val_loss: 208.4087 - val_mean_absolute_error: 6.3288
# Epoch 18/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 86.5430 - mean_absolute_error: 4.6621 - val_loss: 196.3346 - val_mean_absolute_error: 6.4520
# Epoch 19/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 92.6172 - mean_absolute_error: 4.7628 - val_loss: 201.1421 - val_mean_absolute_error: 6.3656
# Epoch 20/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 96.8853 - mean_absolute_error: 4.6627 - val_loss: 198.9509 - val_mean_absolute_error: 6.4480
# Epoch 21/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 79.8252 - mean_absolute_error: 4.5932 - val_loss: 196.6505 - val_mean_absolute_error: 6.4536
# Epoch 22/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 130.8559 - mean_absolute_error: 5.6761 - val_loss: 194.2397 - val_mean_absolute_error: 6.7791
# Epoch 23/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 82.3701 - mean_absolute_error: 4.4837 - val_loss: 202.5993 - val_mean_absolute_error: 6.4034
# Epoch 24/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 85.4360 - mean_absolute_error: 4.6699 - val_loss: 199.3112 - val_mean_absolute_error: 6.5454
# Epoch 25/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89.2806 - mean_absolute_error: 4.8031 - val_loss: 208.6756 - val_mean_absolute_error: 6.4278
# Epoch 26/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 69.6325 - mean_absolute_error: 4.2397 - val_loss: 201.7934 - val_mean_absolute_error: 6.6981
# Epoch 27/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 78.5141 - mean_absolute_error: 4.4202 - val_loss: 208.9180 - val_mean_absolute_error: 6.8859
# Epoch 28/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 87.1486 - mean_absolute_error: 4.5667 - val_loss: 203.6855 - val_mean_absolute_error: 7.0232
# Epoch 29/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 82.3638 - mean_absolute_error: 4.6026 - val_loss: 203.0768 - val_mean_absolute_error: 6.5942
# Epoch 30/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 84.4940 - mean_absolute_error: 4.7521 - val_loss: 205.0117 - val_mean_absolute_error: 6.9399
# Epoch 31/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 100.0722 - mean_absolute_error: 4.8772 - val_loss: 205.2203 - val_mean_absolute_error: 6.6854
# Epoch 32/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 63.0076 - mean_absolute_error: 4.1532 - val_loss: 205.9216 - val_mean_absolute_error: 6.5184
# Epoch 33/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 94.3156 - mean_absolute_error: 4.9526 - val_loss: 206.1911 - val_mean_absolute_error: 6.6351
# Epoch 34/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 81.5379 - mean_absolute_error: 4.5424 - val_loss: 208.6906 - val_mean_absolute_error: 6.5985
# Epoch 35/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 63.5169 - mean_absolute_error: 4.2187 - val_loss: 210.8039 - val_mean_absolute_error: 7.2281
# Epoch 36/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 85.1200 - mean_absolute_error: 4.5210 - val_loss: 209.7760 - val_mean_absolute_error: 6.5970
# Epoch 37/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 74.2860 - mean_absolute_error: 4.3211 - val_loss: 209.6256 - val_mean_absolute_error: 7.0432
# Epoch 38/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 82.0875 - mean_absolute_error: 4.5723 - val_loss: 214.1341 - val_mean_absolute_error: 7.0920
# Epoch 39/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 75.2521 - mean_absolute_error: 4.2842 - val_loss: 219.8108 - val_mean_absolute_error: 7.7620
# Epoch 40/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 77.6524 - mean_absolute_error: 4.5788 - val_loss: 213.6678 - val_mean_absolute_error: 6.9158
# Epoch 41/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 87.0981 - mean_absolute_error: 4.3783 - val_loss: 209.4261 - val_mean_absolute_error: 6.8416
# Epoch 42/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 88.1249 - mean_absolute_error: 4.4852 - val_loss: 225.7599 - val_mean_absolute_error: 7.8911
# Epoch 43/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 73.6544 - mean_absolute_error: 4.5063 - val_loss: 218.2831 - val_mean_absolute_error: 7.0841
# Epoch 44/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89.5582 - mean_absolute_error: 4.5557 - val_loss: 215.2400 - val_mean_absolute_error: 6.6405
# Epoch 45/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 58.3185 - mean_absolute_error: 3.8487 - val_loss: 224.6644 - val_mean_absolute_error: 7.6139
# Epoch 46/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 67.3995 - mean_absolute_error: 4.2177 - val_loss: 217.6760 - val_mean_absolute_error: 6.9456
# Epoch 47/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 58.5724 - mean_absolute_error: 4.0902 - val_loss: 222.3736 - val_mean_absolute_error: 7.0342
# Epoch 48/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.6079 - mean_absolute_error: 3.9043 - val_loss: 217.7371 - val_mean_absolute_error: 7.0605
# Epoch 49/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 61.0798 - mean_absolute_error: 4.0317 - val_loss: 214.9131 - val_mean_absolute_error: 6.7944
# Epoch 50/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 69.0971 - mean_absolute_error: 4.2504 - val_loss: 217.4858 - val_mean_absolute_error: 6.9349
# Epoch 51/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 107.5131 - mean_absolute_error: 4.8685 - val_loss: 223.5450 - val_mean_absolute_error: 7.1976
# Epoch 52/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 84.7171 - mean_absolute_error: 4.5218 - val_loss: 226.5721 - val_mean_absolute_error: 7.3077
# Epoch 53/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 92.8922 - mean_absolute_error: 4.6965 - val_loss: 221.0094 - val_mean_absolute_error: 7.1657
# Epoch 54/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 64.0764 - mean_absolute_error: 3.9698 - val_loss: 221.6891 - val_mean_absolute_error: 7.1900
# Epoch 55/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 60.8424 - mean_absolute_error: 3.9828 - val_loss: 231.2713 - val_mean_absolute_error: 7.5282
# Epoch 56/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 66.5798 - mean_absolute_error: 4.0284 - val_loss: 222.2517 - val_mean_absolute_error: 6.9199
# Epoch 57/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.5067 - mean_absolute_error: 3.6685 - val_loss: 240.5584 - val_mean_absolute_error: 8.0379
# Epoch 58/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 59.8653 - mean_absolute_error: 4.0517 - val_loss: 227.0786 - val_mean_absolute_error: 7.3399
# Epoch 59/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55.8141 - mean_absolute_error: 3.8845 - val_loss: 234.3752 - val_mean_absolute_error: 7.5938
# Epoch 60/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 59.8761 - mean_absolute_error: 3.9654 - val_loss: 229.5773 - val_mean_absolute_error: 7.3104
# Epoch 61/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52.5886 - mean_absolute_error: 3.7516 - val_loss: 226.8300 - val_mean_absolute_error: 7.0410
# Epoch 62/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 57.9779 - mean_absolute_error: 3.8276 - val_loss: 226.4352 - val_mean_absolute_error: 7.0861
# Epoch 63/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 65.1357 - mean_absolute_error: 4.2509 - val_loss: 238.8840 - val_mean_absolute_error: 7.6185
# Epoch 64/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.4821 - mean_absolute_error: 3.5898 - val_loss: 235.7519 - val_mean_absolute_error: 7.4607
# Epoch 65/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.5681 - mean_absolute_error: 3.5855 - val_loss: 240.6883 - val_mean_absolute_error: 7.8527
# Epoch 66/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52.2421 - mean_absolute_error: 3.7808 - val_loss: 235.2593 - val_mean_absolute_error: 7.3460
# Epoch 67/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.5341 - mean_absolute_error: 3.6127 - val_loss: 230.2031 - val_mean_absolute_error: 7.3399
# Epoch 68/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95.5445 - mean_absolute_error: 4.6475 - val_loss: 228.5956 - val_mean_absolute_error: 7.0148
# Epoch 69/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.7833 - mean_absolute_error: 3.7407 - val_loss: 229.6685 - val_mean_absolute_error: 7.2898
# Epoch 70/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.1965 - mean_absolute_error: 3.5726 - val_loss: 240.6395 - val_mean_absolute_error: 7.6840
# Epoch 71/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.7428 - mean_absolute_error: 3.5114 - val_loss: 248.2272 - val_mean_absolute_error: 7.9234
# Epoch 72/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.7343 - mean_absolute_error: 3.6933 - val_loss: 228.0697 - val_mean_absolute_error: 7.1263
# Epoch 73/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 57.6248 - mean_absolute_error: 3.8610 - val_loss: 242.4448 - val_mean_absolute_error: 7.5922
# Epoch 74/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 84.8610 - mean_absolute_error: 4.8304 - val_loss: 220.5616 - val_mean_absolute_error: 6.9384
# Epoch 75/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.6959 - mean_absolute_error: 3.8625 - val_loss: 219.8574 - val_mean_absolute_error: 6.7405
# Epoch 76/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 70.2698 - mean_absolute_error: 4.3096 - val_loss: 232.5124 - val_mean_absolute_error: 7.3104
# Epoch 77/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.6805 - mean_absolute_error: 3.6434 - val_loss: 237.3773 - val_mean_absolute_error: 7.5852
# Epoch 78/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.8863 - mean_absolute_error: 3.6592 - val_loss: 245.1322 - val_mean_absolute_error: 7.7492
# Epoch 79/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.4603 - mean_absolute_error: 3.5721 - val_loss: 223.7422 - val_mean_absolute_error: 6.9814
# Epoch 80/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.2985 - mean_absolute_error: 3.4875 - val_loss: 235.4909 - val_mean_absolute_error: 7.3385
# Epoch 81/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.8782 - mean_absolute_error: 3.5325 - val_loss: 238.1639 - val_mean_absolute_error: 7.5277
# Epoch 82/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.4352 - mean_absolute_error: 3.5665 - val_loss: 239.4518 - val_mean_absolute_error: 7.3854
# Epoch 83/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.6479 - mean_absolute_error: 3.5127 - val_loss: 250.9155 - val_mean_absolute_error: 7.7929
# Epoch 84/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.4759 - mean_absolute_error: 3.5663 - val_loss: 234.1391 - val_mean_absolute_error: 7.2231
# Epoch 85/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.5831 - mean_absolute_error: 3.7720 - val_loss: 232.3639 - val_mean_absolute_error: 7.1385
# Epoch 86/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.9270 - mean_absolute_error: 3.5140 - val_loss: 246.5989 - val_mean_absolute_error: 7.5308
# Epoch 87/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.4728 - mean_absolute_error: 3.3067 - val_loss: 242.1543 - val_mean_absolute_error: 7.3892
# Epoch 88/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 56.0585 - mean_absolute_error: 3.7606 - val_loss: 239.0959 - val_mean_absolute_error: 7.3183
# Epoch 89/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.7253 - mean_absolute_error: 3.6824 - val_loss: 234.4711 - val_mean_absolute_error: 7.2074
# Epoch 90/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.6257 - mean_absolute_error: 3.4221 - val_loss: 245.1177 - val_mean_absolute_error: 7.4138
# Epoch 91/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89.8111 - mean_absolute_error: 5.0740 - val_loss: 226.7093 - val_mean_absolute_error: 7.0963
# Epoch 92/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.4478 - mean_absolute_error: 3.7848 - val_loss: 242.5818 - val_mean_absolute_error: 7.3992
# Epoch 93/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.6882 - mean_absolute_error: 3.3718 - val_loss: 238.7227 - val_mean_absolute_error: 7.2756
# Epoch 94/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 59.0634 - mean_absolute_error: 3.8572 - val_loss: 243.1341 - val_mean_absolute_error: 7.3597
# Epoch 95/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 59.8452 - mean_absolute_error: 3.9801 - val_loss: 249.0863 - val_mean_absolute_error: 7.5821
# Epoch 96/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.2892 - mean_absolute_error: 3.5287 - val_loss: 243.4473 - val_mean_absolute_error: 7.3237
# Epoch 97/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.1591 - mean_absolute_error: 3.9454 - val_loss: 234.5409 - val_mean_absolute_error: 7.2285
# Epoch 98/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 57.3487 - mean_absolute_error: 4.0771 - val_loss: 248.1674 - val_mean_absolute_error: 7.5435
# Epoch 99/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.8782 - mean_absolute_error: 3.6309 - val_loss: 238.5799 - val_mean_absolute_error: 7.2130
# Epoch 100/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.3803 - mean_absolute_error: 3.5379 - val_loss: 253.2791 - val_mean_absolute_error: 7.5633
# Epoch 101/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.6895 - mean_absolute_error: 3.1384 - val_loss: 242.7260 - val_mean_absolute_error: 7.2727
# Epoch 102/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 58.0742 - mean_absolute_error: 3.9376 - val_loss: 236.9725 - val_mean_absolute_error: 7.2185
# Epoch 103/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.8222 - mean_absolute_error: 3.8761 - val_loss: 251.3466 - val_mean_absolute_error: 7.6950
# Epoch 104/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.0211 - mean_absolute_error: 3.3874 - val_loss: 257.4061 - val_mean_absolute_error: 7.7537
# Epoch 105/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.6729 - mean_absolute_error: 3.6405 - val_loss: 264.8857 - val_mean_absolute_error: 8.0512
# Epoch 106/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.8899 - mean_absolute_error: 3.8228 - val_loss: 247.2181 - val_mean_absolute_error: 7.3981
# Epoch 107/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.9113 - mean_absolute_error: 3.2547 - val_loss: 242.4609 - val_mean_absolute_error: 7.3292
# Epoch 108/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.9184 - mean_absolute_error: 3.6310 - val_loss: 240.8489 - val_mean_absolute_error: 7.5253
# Epoch 109/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.5794 - mean_absolute_error: 3.3803 - val_loss: 250.0997 - val_mean_absolute_error: 7.4847
# Epoch 110/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.4196 - mean_absolute_error: 3.1405 - val_loss: 250.3984 - val_mean_absolute_error: 7.3946
# Epoch 111/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.5609 - mean_absolute_error: 3.3053 - val_loss: 252.3456 - val_mean_absolute_error: 7.4928
# Epoch 112/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.1741 - mean_absolute_error: 3.2831 - val_loss: 241.0639 - val_mean_absolute_error: 7.1924
# Epoch 113/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.1063 - mean_absolute_error: 3.2247 - val_loss: 256.3861 - val_mean_absolute_error: 7.4847
# Epoch 114/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.6681 - mean_absolute_error: 3.4894 - val_loss: 252.0149 - val_mean_absolute_error: 7.4094
# Epoch 115/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.5158 - mean_absolute_error: 3.3287 - val_loss: 232.7191 - val_mean_absolute_error: 7.0197
# Epoch 116/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.3541 - mean_absolute_error: 3.3849 - val_loss: 258.2075 - val_mean_absolute_error: 7.6631
# Epoch 117/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.6824 - mean_absolute_error: 3.2522 - val_loss: 234.6480 - val_mean_absolute_error: 7.0664
# Epoch 118/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.3423 - mean_absolute_error: 3.4897 - val_loss: 257.0157 - val_mean_absolute_error: 7.5852
# Epoch 119/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.6590 - mean_absolute_error: 3.4882 - val_loss: 248.5043 - val_mean_absolute_error: 7.4328
# Epoch 120/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.9466 - mean_absolute_error: 3.4695 - val_loss: 238.3250 - val_mean_absolute_error: 7.2064
# Epoch 121/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 56.6891 - mean_absolute_error: 3.9512 - val_loss: 245.6800 - val_mean_absolute_error: 7.3890
# Epoch 122/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.2064 - mean_absolute_error: 3.3221 - val_loss: 249.4756 - val_mean_absolute_error: 7.4377
# Epoch 123/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.0410 - mean_absolute_error: 3.5149 - val_loss: 253.2280 - val_mean_absolute_error: 7.4557
# Epoch 124/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.2998 - mean_absolute_error: 3.2160 - val_loss: 261.7673 - val_mean_absolute_error: 7.7635
# Epoch 125/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.9945 - mean_absolute_error: 2.9844 - val_loss: 261.6161 - val_mean_absolute_error: 7.6883
# Epoch 126/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.2436 - mean_absolute_error: 3.0507 - val_loss: 251.0872 - val_mean_absolute_error: 7.4086
# Epoch 127/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.6974 - mean_absolute_error: 3.0556 - val_loss: 244.2222 - val_mean_absolute_error: 7.2841
# Epoch 128/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.4377 - mean_absolute_error: 3.0078 - val_loss: 241.0757 - val_mean_absolute_error: 7.2550
# Epoch 129/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.6961 - mean_absolute_error: 3.2106 - val_loss: 247.8206 - val_mean_absolute_error: 7.3500
# Epoch 130/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.2936 - mean_absolute_error: 2.8692 - val_loss: 254.6020 - val_mean_absolute_error: 7.4402
# Epoch 131/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.6087 - mean_absolute_error: 3.0475 - val_loss: 263.1842 - val_mean_absolute_error: 7.6870
# Epoch 132/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.3720 - mean_absolute_error: 3.0077 - val_loss: 245.7312 - val_mean_absolute_error: 7.2848
# Epoch 133/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.2546 - mean_absolute_error: 3.1850 - val_loss: 245.3329 - val_mean_absolute_error: 7.2454
# Epoch 134/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 62.5399 - mean_absolute_error: 3.8348 - val_loss: 263.2334 - val_mean_absolute_error: 7.8616
# Epoch 135/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.6034 - mean_absolute_error: 3.7371 - val_loss: 242.0304 - val_mean_absolute_error: 7.1600
# Epoch 136/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.5156 - mean_absolute_error: 3.0058 - val_loss: 254.4708 - val_mean_absolute_error: 7.3796
# Epoch 137/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.9049 - mean_absolute_error: 3.6974 - val_loss: 254.0403 - val_mean_absolute_error: 7.5345
# Epoch 138/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.9845 - mean_absolute_error: 3.0694 - val_loss: 248.8261 - val_mean_absolute_error: 7.3059
# Epoch 139/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.7781 - mean_absolute_error: 2.9528 - val_loss: 257.4409 - val_mean_absolute_error: 7.4437
# Epoch 140/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.4744 - mean_absolute_error: 3.5574 - val_loss: 280.4268 - val_mean_absolute_error: 7.9755
# Epoch 141/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.0512 - mean_absolute_error: 2.9682 - val_loss: 253.6112 - val_mean_absolute_error: 7.3059
# Epoch 142/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.5313 - mean_absolute_error: 3.4994 - val_loss: 273.0679 - val_mean_absolute_error: 7.8108
# Epoch 143/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.8930 - mean_absolute_error: 3.2233 - val_loss: 256.9892 - val_mean_absolute_error: 7.3828
# Epoch 144/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.6125 - mean_absolute_error: 3.1838 - val_loss: 252.2682 - val_mean_absolute_error: 7.4036
# Epoch 145/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.2274 - mean_absolute_error: 2.8604 - val_loss: 263.9471 - val_mean_absolute_error: 7.5184
# Epoch 146/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.8323 - mean_absolute_error: 3.0839 - val_loss: 250.7325 - val_mean_absolute_error: 7.3429
# Epoch 147/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.3089 - mean_absolute_error: 2.9050 - val_loss: 250.4378 - val_mean_absolute_error: 7.2822
# Epoch 148/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.2544 - mean_absolute_error: 2.8606 - val_loss: 266.6059 - val_mean_absolute_error: 7.5037
# Epoch 149/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.0642 - mean_absolute_error: 2.8950 - val_loss: 251.4749 - val_mean_absolute_error: 7.3089
# Epoch 150/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.7340 - mean_absolute_error: 3.1779 - val_loss: 262.2551 - val_mean_absolute_error: 7.5640
# Epoch 151/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.9104 - mean_absolute_error: 3.3978 - val_loss: 267.8165 - val_mean_absolute_error: 7.6167
# Epoch 152/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.3627 - mean_absolute_error: 2.6959 - val_loss: 264.3875 - val_mean_absolute_error: 7.5493
# Epoch 153/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.7648 - mean_absolute_error: 3.1266 - val_loss: 271.3402 - val_mean_absolute_error: 7.5688
# Epoch 154/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.4015 - mean_absolute_error: 3.3400 - val_loss: 255.5265 - val_mean_absolute_error: 7.3555
# Epoch 155/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.1143 - mean_absolute_error: 3.0001 - val_loss: 264.3803 - val_mean_absolute_error: 7.5892
# Epoch 156/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.7158 - mean_absolute_error: 2.9444 - val_loss: 271.4810 - val_mean_absolute_error: 7.6410
# Epoch 157/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.3071 - mean_absolute_error: 2.8560 - val_loss: 245.8908 - val_mean_absolute_error: 7.1764
# Epoch 158/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.2737 - mean_absolute_error: 3.0573 - val_loss: 259.1888 - val_mean_absolute_error: 7.3539
# Epoch 159/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.5159 - mean_absolute_error: 2.8584 - val_loss: 264.8690 - val_mean_absolute_error: 7.6106
# Epoch 160/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.6376 - mean_absolute_error: 2.7106 - val_loss: 270.2290 - val_mean_absolute_error: 7.6546
# Epoch 161/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.3490 - mean_absolute_error: 2.8702 - val_loss: 254.9390 - val_mean_absolute_error: 7.3330
# Epoch 162/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.9185 - mean_absolute_error: 2.7686 - val_loss: 258.2717 - val_mean_absolute_error: 7.4778
# Epoch 163/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.5645 - mean_absolute_error: 3.0548 - val_loss: 238.8395 - val_mean_absolute_error: 7.0621
# Epoch 164/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.0905 - mean_absolute_error: 3.0000 - val_loss: 275.9388 - val_mean_absolute_error: 7.8173
# Epoch 165/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 70.3190 - mean_absolute_error: 3.8269 - val_loss: 268.2663 - val_mean_absolute_error: 7.5342
# Epoch 166/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.6605 - mean_absolute_error: 2.9302 - val_loss: 270.8958 - val_mean_absolute_error: 7.8007
# Epoch 167/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.9368 - mean_absolute_error: 3.0133 - val_loss: 276.9873 - val_mean_absolute_error: 7.6311
# Epoch 168/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.8666 - mean_absolute_error: 2.7029 - val_loss: 266.0333 - val_mean_absolute_error: 7.6148
# Epoch 169/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.3809 - mean_absolute_error: 3.3079 - val_loss: 273.5313 - val_mean_absolute_error: 7.7215
# Epoch 170/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.7658 - mean_absolute_error: 2.8919 - val_loss: 265.0929 - val_mean_absolute_error: 7.5497
# Epoch 171/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.3428 - mean_absolute_error: 3.5834 - val_loss: 263.0228 - val_mean_absolute_error: 7.6608
# Epoch 172/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.3481 - mean_absolute_error: 3.0120 - val_loss: 243.4864 - val_mean_absolute_error: 7.1470
# Epoch 173/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 57.2611 - mean_absolute_error: 3.5060 - val_loss: 269.2133 - val_mean_absolute_error: 7.5185
# Epoch 174/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52.5410 - mean_absolute_error: 3.7139 - val_loss: 264.6801 - val_mean_absolute_error: 7.4210
# Epoch 175/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.5630 - mean_absolute_error: 3.3029 - val_loss: 247.0197 - val_mean_absolute_error: 7.1756
# Epoch 176/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.9041 - mean_absolute_error: 2.9275 - val_loss: 262.3926 - val_mean_absolute_error: 7.3877
# Epoch 177/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.9898 - mean_absolute_error: 2.9571 - val_loss: 266.4769 - val_mean_absolute_error: 7.5314
# Epoch 178/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.6308 - mean_absolute_error: 2.7250 - val_loss: 261.7314 - val_mean_absolute_error: 7.5401
# Epoch 179/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 113.9993 - mean_absolute_error: 4.5540 - val_loss: 254.3326 - val_mean_absolute_error: 7.2708
# Epoch 180/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 76.7088 - mean_absolute_error: 4.3078 - val_loss: 253.5664 - val_mean_absolute_error: 7.3405
# Epoch 181/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.2669 - mean_absolute_error: 3.0415 - val_loss: 258.3829 - val_mean_absolute_error: 7.4274
# Epoch 182/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.0898 - mean_absolute_error: 2.8359 - val_loss: 256.3566 - val_mean_absolute_error: 7.3490
# Epoch 183/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.8999 - mean_absolute_error: 2.6494 - val_loss: 257.7346 - val_mean_absolute_error: 7.3907
# Epoch 184/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.6285 - mean_absolute_error: 2.7993 - val_loss: 261.9300 - val_mean_absolute_error: 7.4915
# Epoch 185/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.1040 - mean_absolute_error: 2.7808 - val_loss: 261.9624 - val_mean_absolute_error: 7.4108
# Epoch 186/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.2225 - mean_absolute_error: 2.6935 - val_loss: 264.2065 - val_mean_absolute_error: 7.4873
# Epoch 187/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.2488 - mean_absolute_error: 2.8197 - val_loss: 263.5159 - val_mean_absolute_error: 7.3980
# Epoch 188/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.9081 - mean_absolute_error: 2.6533 - val_loss: 270.3751 - val_mean_absolute_error: 7.5863
# Epoch 189/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.8846 - mean_absolute_error: 3.0120 - val_loss: 264.5586 - val_mean_absolute_error: 7.4502
# Epoch 190/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.8307 - mean_absolute_error: 2.8509 - val_loss: 270.2137 - val_mean_absolute_error: 7.5235
# Epoch 191/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.1758 - mean_absolute_error: 2.6105 - val_loss: 273.5828 - val_mean_absolute_error: 7.5902
# Epoch 192/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.6950 - mean_absolute_error: 3.2544 - val_loss: 260.2645 - val_mean_absolute_error: 7.3573
# Epoch 193/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.0515 - mean_absolute_error: 2.5644 - val_loss: 271.5621 - val_mean_absolute_error: 7.5795
# Epoch 194/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.9644 - mean_absolute_error: 2.7729 - val_loss: 270.9722 - val_mean_absolute_error: 7.5948
# Epoch 195/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.8370 - mean_absolute_error: 3.0213 - val_loss: 276.7941 - val_mean_absolute_error: 7.6069
# Epoch 196/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.9290 - mean_absolute_error: 2.7185 - val_loss: 267.2343 - val_mean_absolute_error: 7.5061
# Epoch 197/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.8638 - mean_absolute_error: 2.6437 - val_loss: 287.1828 - val_mean_absolute_error: 7.8984
# Epoch 198/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.0887 - mean_absolute_error: 2.5914 - val_loss: 271.4540 - val_mean_absolute_error: 7.4540
# Epoch 199/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.5285 - mean_absolute_error: 2.7277 - val_loss: 266.7770 - val_mean_absolute_error: 7.4279
# Epoch 200/200
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.5871 - mean_absolute_error: 2.9541 - val_loss: 275.3105 - val_mean_absolute_error: 7.7269

# %%
def plot_predictions(model):
    train_pred = model.predict(X_train)
    valid_pred = model.predict(X_valid)

    # plot all of predictions with the observations
    plt.plot(train_date, train_pred, label='train predict')
    plt.plot(train_date, y_train, label='train')

    plt.plot(valid_date, valid_pred, label='valid predict')
    plt.plot(valid_date, y_valid, label='valid')

    plt.legend()
    

plot_predictions(model)
# Out:
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step

# %% [markdown]
# ### Test Prediction

# %%
test_df = pd.read_csv('Test_set.csv', index_col='_id')
test_df['provinceID'] = encode.fit_transform(test_df['PROVINCE']).astype('int')
test_df.drop(columns=['Disease'], inplace=True)

test_df['Count'] = 0
test_df
# Out:
#        Year    PROVINCE  Week_no  provinceID  Count
# _id
# 40195  2023     Bangkok        1           2      0
# 40196  2023     Bangkok        2           2      0
# 40197  2023     Bangkok        3           2      0
# 40198  2023     Bangkok        4           2      0
# 40199  2023     Bangkok        5           2      0
# ...     ...         ...      ...         ...    ...
# 43385  2023  Narathiwat       37          32      0
# 43386  2023  Narathiwat       38          32      0
# 43387  2023  Narathiwat       39          32      0
# 43388  2023  Narathiwat       40          32      0
# 43389  2023  Narathiwat       41          32      0
#
# [3195 rows x 5 columns]

# %%
predicted_df = df_prep.drop(columns=['PROVINCE', 'Count'])
predicted_df = predicted_df.sort_values(['provinceID', 'Week_no'])
predicted_df.bfill(inplace=True)
predicted_df['Predict'] = model.predict(predicted_df.drop(columns='Week_no')).astype('int')
predicted_df
# Out:
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
#             Week_no  provinceID  lag4_diff  lag8_diff  lag12_diff  Predict
# Date
# 2022-01-04        2           0        0.0        0.0         0.0        8
# 2022-01-11        3           0        0.0        0.0         0.0        8
# 2022-01-18        4           0        0.0        0.0         0.0        8
# 2022-01-25        5           0        0.0        0.0         0.0        8
# 2022-02-01        6           0        0.0        0.0         0.0        8
# ...             ...         ...        ...        ...         ...      ...
# 2022-11-22       48          76        2.0       -3.0       -78.0        7
# 2022-11-29       49          76       -2.0       -3.0       -59.0        6
# 2022-12-06       50          76       -5.0       -5.0       -43.0        6
# 2022-12-13       51          76       -8.0        3.0       -26.0       12
# 2022-12-20       52          76        1.0        3.0        -2.0        6
#
# [3927 rows x 6 columns]

# %%
predicted_df = predicted_df.sample(3195).sort_values(['provinceID', 'Week_no'])
predicted_df.shape
# Out:
# (3195, 6)

# %%
test_df = test_df.sort_values(['provinceID', 'Week_no'])
test_df['Count'] = predicted_df['Predict'].values
test_df
# Out:
#        Year       PROVINCE  Week_no  provinceID  Count
# _id
# 41230  2023  Amnat Charoen        1           0      8
# 41231  2023  Amnat Charoen        2           0      8
# 41232  2023  Amnat Charoen        3           0      8
# 41233  2023  Amnat Charoen        4           0      8
# 41234  2023  Amnat Charoen        5           0      8
# ...     ...            ...      ...         ...    ...
# 41184  2023       Yasothon       38          76     13
# 41185  2023       Yasothon       39          76      6
# 41186  2023       Yasothon       40          76      6
# 41187  2023       Yasothon       41          76     12
# 41188  2023       Yasothon       42          76      6
#
# [3195 rows x 5 columns]

# %%
test_df = test_df.sort_index()
test_df = test_df[['Count']]
test_df = test_df.rename(columns={'Count': 'Pred'})
test_df
# Out:
#        Pred
# _id
# 40195     3
# 40196     2
# 40197     2
# 40198     2
# 40199     3
# ...     ...
# 43385     6
# 43386     3
# 43387     6
# 43388     2
# 43389     6
#
# [3195 rows x 1 columns]

# %%
test_df.to_csv('submission.csv')
